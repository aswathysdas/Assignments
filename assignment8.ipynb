# %% [markdown]
# #### ASSIGNMENT 8

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\archive\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.barplot(x=df.Species,y=df.SepalWidthCm).set_title('SEPAL WIDTH OF EACH SPECIES')
plt.show()

# %%
sns.pairplot(df)
plt.suptitle('PAIR PLOT OF SPECIES')
plt.show()

# %%
sns.lineplot(x=df.SepalLengthCm,y=df.Species).set_title('SEPAL LENGTH OF EACH SPECIES')
plt.show()
